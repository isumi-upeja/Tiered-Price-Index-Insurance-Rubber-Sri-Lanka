# %%
import numpy as np
from scipy.stats import norm
import pandas as pd

# ==========================================
# ALL INPUTS — CHANGE ANYTHING HERE
# ==========================================
# Grade Data
grades = ['RSS 1', 'RSS 3']
spot_prices = [325.34, 308]       # Latest market prices (LKR)
volatilities = [23.91, 23.97]     # Annualised volatility (%)
hist_means = [279.46, 264.68]     # Historical mean prices (LKR)

# Contract Parameters
r = 8.58                          # Risk-free rate 2025 January 10 (%)
T = 1.0                           # 1-year contract (as in your thesis)
prod_cost = 210                   # Production cost floor (LKR)

# ==========================================
# BLACK-SCHOLES PUT OPTION FUNCTION
# ==========================================
def black_scholes_put(S, K, T, r, sigma):
    r_dec = r / 100
    sigma_dec = sigma / 100
    d1 = (np.log(S / K) + (r_dec + 0.5 * sigma_dec**2) * T) / (sigma_dec * np.sqrt(T))
    d2 = d1 - sigma_dec * np.sqrt(T)
    put_price = (K * np.exp(-r_dec * T) * norm.cdf(-d2)) - (S * norm.cdf(-d1))
    return put_price

# ==========================================
# RUN BLACK-SCHOLES FOR ALL GRADES AND TIERS
# ==========================================
results = []

for i in range(len(grades)):
    grade = grades[i]
    S = spot_prices[i]
    vol = volatilities[i]
    h_mean = hist_means[i]
    
    scenarios = {
        '100% Market'     : S,
        '95% Market'      : S * 0.95,
        'Historical Mean' : h_mean,
        'Production Cost' : prod_cost
    }
    
    for label, K in scenarios.items():
        premium_bs = black_scholes_put(S, K, T, r, vol)
        
        results.append({
            'Grade'                  : grade,
            'Scenario'               : label,
            'Strike (K)'             : round(K, 2),
            'BS Premium (LKR/kg)'    : round(premium_bs, 2)
        })

# ==========================================
# FINAL TABLE OUTPUT
# ==========================================
df_final = pd.DataFrame(results)
print("=== BLACK-SCHOLES PRICE-ONLY PREMIUMS (1-YEAR CONTRACT) ===")
print(df_final.to_string(index=False))
# Out:
# === BLACK-SCHOLES PRICE-ONLY PREMIUMS (1-YEAR CONTRACT) ===
# Grade        Scenario  Strike (K)  BS Premium (LKR/kg)
# RSS 1     100% Market      325.34                18.19
# RSS 1      95% Market      309.07                12.74
# RSS 1 Historical Mean      279.46                 5.79
# RSS 1 Production Cost      210.00                 0.30
# RSS 3     100% Market      308.00                17.29
# RSS 3      95% Market      292.60                12.12
# RSS 3 Historical Mean      264.68                 5.54
# RSS 3 Production Cost      210.00                 0.55
